# %% [markdown]
# # **Programming Assessment \#4**
#
# Names: MAJARREIS, Isaiah Thane | RUELOS, Miguel Antonio
#
# More information on the assessment is found in our Canvas course.

# %% [markdown]
# # **Load Data**
#
# *While you don't have to separate your code into blocks, it might be easier if you separated loading your data from actually implementation of your code. Consider placing all loading of data into the code block below.*

# %%
from collections import defaultdict
import nltk
from nltk.corpus import gutenberg
from nltk.tokenize import word_tokenize
from nltk.metrics import edit_distance
from tabulate import tabulate

# Error Model
error_model = {}

with open('count_1edit.txt', 'r') as file:
    for line in file:
        parts = line.strip().split(' ')
        if len(parts) == 2:
            wrong_right, count = parts
            if '|' in wrong_right:
                wrong, right = wrong_right.split('|')
                if wrong and right:
                    if wrong not in error_model:
                        error_model[wrong] = {}
                    error_model[wrong][right] = int(count)
                else:
                    print(f"Issue with line: {line.strip()}")
            else:
                print(f"Issue with line: {line.strip()}")
        else:
            print(f"Issue with line: {line.strip()}")

# Language Model
nltk.download('gutenberg')
corpus = gutenberg.words()
vocab = set(corpus)
word_count = len(corpus)
word_frequency = nltk.FreqDist(corpus)
# Out:
# Issue with line: e|i	917
# Issue with line: a|e	856
# Issue with line: i|e	771
# Issue with line: e|a	749
# Issue with line: a|i	559
# Issue with line: t|te	478
# Issue with line: r|re	392
# Issue with line: s|c	383
# Issue with line: e|ea	354
# Issue with line: a|o	353
# Issue with line: o|a	352
# Issue with line: a|al	352
# Issue with line: i|a	313
# Issue with line: re|r	299
# Issue with line: e|o	295
# Issue with line: ea|e	285
# Issue with line: te|t	271
# Issue with line: l|le	263
# Issue with line: e|es	258
# Issue with line: o|ou	235
# Issue with line: n|m	230
# Issue with line: o|e	216
# Issue with line: a|ai	216
# Issue with line: le|l	215
# Issue with line: n|ne	213
# Issue with line: e|er	211
# Issue with line: c|s	209
# Issue with line: e|ed	206
# Issue with line: a|ac	199
# Issue with line: r|ri	194
# Issue with line: er|re	189
# Issue with line: c|ch	188
# Issue with line: a|an	184
# Issue with line: ne|n	174
# Issue with line: o|u	171
# Issue with line: ar|a	171
# Issue with line: u|e	162
# Issue with line: er|e	162
# Issue with line: e|u	160
# Issue with line: a|ap	159
# Issue with line: se|s	158
# Issue with line: o|om	158
# Issue with line: ou|o	158
# Issue with line: e|y	154
# Issue with line: a|ar	154
# Issue with line: e|en	150
# Issue with line: i|in	146
# Issue with line: n|ns	142
# Issue with line: i|y	142
# Issue with line: m|n	140
# Issue with line: ai|a	139
# Issue with line: es|e	136
# Issue with line: u|i	133
# Issue with line: i|is	133
# Issue with line: u|o	130
# Issue with line: h|he	129
# Issue with line: s|se	128
# Issue with line: o|or	127
# Issue with line: u|a	126
# Issue with line: y|i	125
# Issue with line: a|u	123
# Issue with line: is|i	122
# Issue with line: ei|ie	122
# Issue with line: al|a	122
# Issue with line: el|le	121
# Issue with line: s|st	120
# Issue with line: u|ur	119
# Issue with line: i|u	119
# Issue with line: ed|e	117
# Issue with line: n|ni	116
# Issue with line: he|h	116
# Issue with line: de|d	115
# Issue with line: g|gu	114
# Issue with line: a|as	114
# Issue with line: re|er	113
# Issue with line: an|a	108
# Issue with line: d|t	106
# Issue with line: g|ge	104
# Issue with line: |-	102
# Issue with line: s|sc	101
# Issue with line: i|o	101
# Issue with line: ie|i	101
# Issue with line: e|el	100
# Issue with line: o|i	99
# Issue with line: il|i	99
# Issue with line: ec|e	99
# Issue with line: t|ti	98
# Issue with line: i|it	96
# Issue with line: et|te	96
# Issue with line: w|wh	95
# Issue with line: r|ra	94
# Issue with line: m|me	94
# Issue with line: ic|ci	94
# Issue with line: u|ui	93
# Issue with line: as|a	92
# Issue with line: a|au	90
# Issue with line: a|at	90
# Issue with line: p|pe	88
# Issue with line: c|ci	88
# Issue with line: t|d	87
# Issue with line: i|ie	87
# Issue with line: s|si	86
# Issue with line: en|e	86
# Issue with line: n|n'	85
# Issue with line: d|de	85
# Issue with line: i|ia	84
# Issue with line: in|i	84
# Issue with line: v|ve	83
# Issue with line: ul|u	83
# Issue with line: o|ow	83
# Issue with line: n|ng	83
# Issue with line: in|ni	82
# Issue with line: el|e	82
# Issue with line: o|on	81
# Issue with line: ie|ei	81
# Issue with line: f|fi	81
# Issue with line: ei|e	81
# Issue with line: t|ts	80
# Issue with line: me|m	79
# Issue with line: ac|a	79
# Issue with line: o|ol	78
# Issue with line: k|ke	78
# Issue with line: e |e	78
# Issue with line: or|o	77
# Issue with line: pe|p	76
# Issue with line: n|nt	75
# Issue with line: le|el	75
# Issue with line: t|tr	74
# Issue with line: t|ta	74
# Issue with line: en|ne	74
# Issue with line: ri|r	73
# Issue with line: o|oa	72
# Issue with line: l|li	72
# Issue with line: it|ti	72
# Issue with line: c|co	72
# Issue with line: nt|n	71
# Issue with line: ia|i	71
# Issue with line: ur|u	70
# Issue with line: ck|c	70
# Issue with line: i|im	69
# Issue with line: u|ul	68
# Issue with line: n|nd	68
# Issue with line: de|ed	68
# Issue with line: ti|t	67
# Issue with line: is|si	67
# Issue with line: e|et	67
# Issue with line: e|ei	66
# Issue with line: i|ic	65
# Issue with line: c|t	65
# Issue with line: c|ce	65
# Issue with line: t|c	64
# Issue with line: se|es	64
# Issue with line: ke|k	64
# Issue with line: i|io	64
# Issue with line: u|un	63
# Issue with line: t|to	63
# Issue with line: s|sh	62
# Issue with line: ne|en	62
# Issue with line: ce|c	62
# Issue with line: u|uc	61
# Issue with line: u|ua	61
# Issue with line: s|z	61
# Issue with line: ni|n	61
# Issue with line: i|il	61
# Issue with line: >|>s	61
# Issue with line: s|t	60
# Issue with line: r|ro	60
# Issue with line: it|i	60
# Issue with line: at|a	60
# Issue with line: p|pr	59
# Issue with line: >|>a	59
# Issue with line: c|g	58
# Issue with line: t|th	57
# Issue with line: si|is	57
# Issue with line: a|ag	57
# Issue with line: o|op	56
# Issue with line: ni|in	56
# Issue with line: io|i	56
# Issue with line: ia|ai	56
# Issue with line: t|t'	55
# Issue with line: ue|u	54
# Issue with line: l|ly	54
# Issue with line: wh|w	53
# Issue with line: th|t	53
# Issue with line: oa|o	53
# Issue with line: k|c	53
# Issue with line: ad|a	53
# Issue with line: w|u	52
# Issue with line: ol|o	52
# Issue with line: be|b	52
# Issue with line: r|rt	51
# Issue with line: ow|o	51
# Issue with line: es|se	51
# Issue with line: p|ph	50
# Issue with line: o|oc	50
# Issue with line: >|>p	50
# Issue with line: z|s	49
# Issue with line: y|e	49
# Issue with line: o|os	49
# Issue with line: on|o	49
# Issue with line: n|na	49
# Issue with line: nd|n	49
# Issue with line: me|em	49
# Issue with line: >|>w	49
# Issue with line: >a|>	49
# Issue with line: r|rs	48
# Issue with line: m|mi	48
# Issue with line: f|fe	48
# Issue with line: sc|s	47
# Issue with line: ra|ar	47
# Issue with line: i|ig	47
# Issue with line: ge|g	47
# Issue with line: e|ec	47
# Issue with line: ua|u	46
# Issue with line: p|b	46
# Issue with line: ef|e	46
# Issue with line: d|di	46
# Issue with line: co|c	46
# Issue with line: ch|c	46
# Issue with line: r|l	45
# Issue with line: li|l	45
# Issue with line: i|ip	45
# Issue with line: u|w	44
# Issue with line: b|be	44
# Issue with line: an|na	44
# Issue with line: >|>k	44
# Issue with line: ir|ri	43
# Issue with line: >|>h	43
# Issue with line: y |y	42
# Issue with line: t|tu	42
# Issue with line: ro|or	42
# Issue with line: om|o	42
# Issue with line: l|lo	42
# Issue with line: au|a	42
# Issue with line: ui|u	41
# Issue with line: il|li	41
# Issue with line: h|ho	41
# Issue with line: em|me	41
# Issue with line: b|d	41
# Issue with line: >e|>	41
# Issue with line: v|f	40
# Issue with line: p|pa	40
# Issue with line: a|af	40
# Issue with line: ar|ra	40
# Issue with line: w|we	39
# Issue with line: r|rn	39
# Issue with line: o|ot	39
# Issue with line: f|v	39
# Issue with line: em|e	39
# Issue with line: ct|c	39
# Issue with line: au|ua	39
# Issue with line: >|>i	39
# Issue with line: we|w	38
# Issue with line: us|u	38
# Issue with line: t|s	38
# Issue with line: st|s	38
# Issue with line: si|s	38
# Issue with line: p|pl	38
# Issue with line: ci|ic	38
# Issue with line: xs|x	37
# Issue with line: u|ue	37
# Issue with line: te|et	37
# Issue with line: ph|p	37
# Issue with line: n |n	37
# Issue with line: g|gh	37
# Issue with line: d|b	37
# Issue with line: a |a	37
# Issue with line: >|>e	37
# Issue with line: >h|>	37
# Issue with line: ta|t	36
# Issue with line: f|fr	36
# Issue with line: e|ey	36
# Issue with line: c|ct	36
# Issue with line: v|vi	35
# Issue with line: r|ry	35
# Issue with line: ng|n	35
# Issue with line: i|ir	35
# Issue with line: e|t	35
# Issue with line: ve|v	34
# Issue with line: u|up	34
# Issue with line: to|t	34
# Issue with line: ns|n	34
# Issue with line: l|t	34
# Issue with line: ey|e	34
# Issue with line: c|ca	34
# Issue with line: ti|it	33
# Issue with line: p|pi	33
# Issue with line: o|oe	33
# Issue with line: n|nc	33
# Issue with line: na|an	33
# Issue with line: m|mb	33
# Issue with line: i|id	33
# Issue with line: ic|i	33
# Issue with line: th|ht	32
# Issue with line: r |r	32
# Issue with line: m|mp	32
# Issue with line: m|ma	32
# Issue with line: mn|m	32
# Issue with line: k|h	32
# Issue with line: d|da	32
# Issue with line: c|cr	32
# Issue with line: a|am	32
# Issue with line: ai|ia	32
# Issue with line: tr|t	31
# Issue with line: sh|s	31
# Issue with line: ht|th	31
# Issue with line: c|ck	31
# Issue with line: b|p	31
# Issue with line: vi|v	30
# Issue with line: or|ro	30
# Issue with line: ma|m	30
# Issue with line: g|j	30
# Issue with line: a|ad	30
# Issue with line: ra|r	29
# Issue with line: g|c	29
# Issue with line: ri|ir	28
# Issue with line: oc|o	28
# Issue with line: c|k	28
# Issue with line: ci|c	28
# Issue with line: ye|y	27
# Issue with line: r|e	27
# Issue with line: pi|p	27
# Issue with line: m|mn	27
# Issue with line: ec|ce	27
# Issue with line: ap|a	27
# Issue with line: t |t	26
# Issue with line: s|sa	26
# Issue with line: r|u	26
# Issue with line: ro|r	26
# Issue with line: o|oi	26
# Issue with line: ol|lo	26
# Issue with line: n|d	26
# Issue with line: ig|gi	26
# Issue with line: h|hi	26
# Issue with line: ho|h	26
# Issue with line: fe|f	26
# Issue with line: e|em	26
# Issue with line: am|a	26
# Issue with line: t|h	25
# Issue with line: s|so	25
# Issue with line: r|r'	25
# Issue with line: r|n	25
# Issue with line: op|o	25
# Issue with line: oe|o	25
# Issue with line: at|ta	25
# Issue with line: ae|ea	25
# Issue with line: >|>u	25
# Issue with line: u|us	24
# Issue with line: rs|r	24
# Issue with line: m|mo	24
# Issue with line: mi|m	24
# Issue with line: ir|i	24
# Issue with line: g|d	24
# Issue with line: b|br	24
# Issue with line: E|e	24
# Issue with line: y|ys	23
# Issue with line: y|ym	23
# Issue with line: xc|x	23
# Issue with line: un|u	23
# Issue with line: s|d	23
# Issue with line: su|s	23
# Issue with line: st|ts	23
# Issue with line: pa|p	23
# Issue with line: n|r	23
# Issue with line: k|t	23
# Issue with line: g|gr	23
# Issue with line: e|s	23
# Issue with line: ev|ve	23
# Issue with line: ed|de	23
# Issue with line: q|c	22
# Issue with line: o|og	22
# Issue with line: os|o	22
# Issue with line: of|o	22
# Issue with line: ly|l	22
# Issue with line: id|i	22
# Issue with line: e|eu	22
# Issue with line: et|e	22
# Issue with line: e'|e	22
# Issue with line: d|g	22
# Issue with line: d |d	22
# Issue with line: c|cu	22
# Issue with line: b|bu	22
# Issue with line: y|ye	21
# Issue with line: ue|eu	21
# Issue with line: t|e	21
# Issue with line: ts|t	21
# Issue with line: p|po	21
# Issue with line: o|of	21
# Issue with line: on|no	21
# Issue with line: mi|im	21
# Issue with line: l|r	21
# Issue with line: li|il	21
# Issue with line: l |l	21
# Issue with line: im|mi	21
# Issue with line: ht|h	21
# Issue with line: hi|h	21
# Issue with line: fe|ef	21
# Issue with line: do|d	21
# Issue with line: b|bi	21
# Issue with line: a|y	21
# Issue with line: >s|>	21
# Issue with line: tw|t	20
# Issue with line: s|sw	20
# Issue with line: r|rh	20
# Issue with line: r|rc	20
# Issue with line: pr|p	20
# Issue with line: n|t	20
# Issue with line: n|ny	20
# Issue with line: n|nu	20
# Issue with line: la|l	20
# Issue with line: k |k	20
# Issue with line: eo|e	20
# Issue with line: di|d	20
# Issue with line: cs|c	20
# Issue with line: bu|b	20
# Issue with line: |	19
# Issue with line: x|xc	19
# Issue with line: t|tl	19
# Issue with line: s|sp	19
# Issue with line: ry|r	19
# Issue with line: oi|io	19
# Issue with line: l|i	19
# Issue with line: lo|ol	19
# Issue with line: e|eo	19
# Issue with line: ca|c	19
# Issue with line: >|>d	19
# Issue with line: >i|>	19
# Issue with line: u|ut	18
# Issue with line: ut|u	18
# Issue with line: t|l	18
# Issue with line: tu|t	18
# Issue with line: sa|as	18
# Issue with line: rd|r	18
# Issue with line: ot|o	18
# Issue with line: lo|l	18
# Issue with line: la|al	18
# Issue with line: h|ht	18
# Issue with line: gu|g	18
# Issue with line: e|ef	18
# Issue with line: d|e	18
# Issue with line: a|ay	18
# Issue with line: am|ma	18
# Issue with line: >|>t	18
# Issue with line: >t|>	18
# Issue with line: x|xi	17
# Issue with line: u|uf	17
# Issue with line: sa|s	17
# Issue with line: ru|ur	17
# Issue with line: rt|r	17
# Issue with line: pt|p	17
# Issue with line: po|p	17
# Issue with line: nc|n	17
# Issue with line: iu|ui	17
# Issue with line: im|i	17
# Issue with line: if|fi	17
# Issue with line: ib|bi	17
# Issue with line: h|n	17
# Issue with line: ga|g	17
# Issue with line: fi|f	17
# Issue with line: cu|c	17
# Issue with line: a|l	17
# Issue with line: a|ab	17
# Issue with line: >|>o	17
# Issue with line: u|um	16
# Issue with line: ru|r	16
# Issue with line: p|pt	16
# Issue with line: o |o	16
# Issue with line: nu|n	16
# Issue with line: na|n	16
# Issue with line: l|d	16
# Issue with line: l|b	16
# Issue with line: i|t	16
# Issue with line: i|if	16
# Issue with line: if|i	16
# Issue with line: h|ha	16
# Issue with line: d|n	16
# Issue with line: c|x	16
# Issue with line: c|cs	16
# Issue with line: ce|ec	16
# Issue with line: a|t	16
# Issue with line: P|p	16
# Issue with line: >k|>	16
# Issue with line: x|c	15
# Issue with line: uo|ou	15
# Issue with line: t|p	15
# Issue with line: t|i	15
# Issue with line: r|rd	15
# Issue with line: r|i	15
# Issue with line: r|d	15
# Issue with line: r|a	15
# Issue with line: rn|r	15
# Issue with line: q|qu	15
# Issue with line: n|no	15
# Issue with line: n|l	15
# Issue with line: n'|n	15
# Issue with line: l|ls	15
# Issue with line: i|h	15
# Issue with line: h|e	15
# Issue with line: g|t	15
# Issue with line: e|n	15
# Issue with line: d|ds	15
# Issue with line: a|r	15
# Issue with line: ay|a	15
# Issue with line: >|>r	15
# Issue with line: u|ug	14
# Issue with line: us|su	14
# Issue with line: ta|at	14
# Issue with line: s|x	14
# Issue with line: s|sy	14
# Issue with line: so|s	14
# Issue with line: r|s	14
# Issue with line: r|f	14
# Issue with line: n|s	14
# Issue with line: k|ks	14
# Issue with line: io|oi	14
# Issue with line: h|t	14
# Issue with line: h|i	14
# Issue with line: gi|ig	14
# Issue with line: f|fo	14
# Issue with line: ba|ab	14
# Issue with line: al|la	14
# Issue with line: x|xh	13
# Issue with line: u|ub	13
# Issue with line: uc|u	13
# Issue with line: ua|au	13
# Issue with line: ts|st	13
# Issue with line: s|r	13
# Issue with line: s|a	13
# Issue with line: r|t	13
# Issue with line: n|u	13
# Issue with line: m|ms	13
# Issue with line: mo|m	13
# Issue with line: k|g	13
# Issue with line: gh|g	13
# Issue with line: f|ft	13
# Issue with line: f|fl	13
# Issue with line: fo|f	13
# Issue with line: e|d	13
# Issue with line: ep|e	13
# Issue with line: eg|e	13
# Issue with line: da|d	13
# Issue with line: cl|c	13
# Issue with line: b|bl	13
# Issue with line: a|d	13
# Issue with line: ag|ga	13
# Issue with line: D|d	13
# Issue with line: >|>f	13
# Issue with line: u|r	12
# Issue with line: ur|ru	12
# Issue with line: ud|du	12
# Issue with line: t|n	12
# Issue with line: t|k	12
# Issue with line: s|e	12
# Issue with line: rl|r	12
# Issue with line: q|g	12
# Issue with line: p|f	12
# Issue with line: o|od	12
# Issue with line: oi|o	12
# Issue with line: mo|om	12
# Issue with line: l|e	12
# Issue with line: j|g	12
# Issue with line: id|di	12
# Issue with line: h|u	12
# Issue with line: hu|h	12
# Issue with line: ha|h	12
# Issue with line: g|gn	12
# Issue with line: g|gi	12
# Issue with line: g|ga	12
# Issue with line: fr|f	12
# Issue with line: e|r	12
# Issue with line: e|h	12
# Issue with line: e|e'	12
# Issue with line: ep|pe	12
# Issue with line: eo|oe	12
# Issue with line: c|a	12
# Issue with line: ca|ac	12
# Issue with line: b|bo	12
# Issue with line: bo|b	12
# Issue with line: ba|b	12
# Issue with line: a|ae	12
# Issue with line: >w|>	12
# Issue with line: >m|>	12
# Issue with line: ys|y	11
# Issue with line: t|r	11
# Issue with line: r|p	11
# Issue with line: r|m	11
# Issue with line: pe|ep	11
# Issue with line: o|o'	11
# Issue with line: no|n	11
# Issue with line: l|w	11
# Issue with line: l|la	11
# Issue with line: lu|ul	11
# Issue with line: i|l	11
# Issue with line: iu|i	11
# Issue with line: h|hy	11
# Issue with line: hr|h	11
# Issue with line: g|k	11
# Issue with line: e|c	11
# Issue with line: e|b	11
# Issue with line: ex|e	11
# Issue with line: d|r	11
# Issue with line: d|dg	11
# Issue with line: c|q	11
# Issue with line: c|p	11
# Issue with line: c|cl	11
# Issue with line: ah|ha	11
# Issue with line: >|>m	11
# Issue with line: y|u	10
# Issue with line: y|o	10
# Issue with line: w|r	10
# Issue with line: vo|v	10
# Issue with line: u|y	10
# Issue with line: u|s	10
# Issue with line: u|n	10
# Issue with line: u|l	10
# Issue with line: ul|lu	10
# Issue with line: t|tw	10
# Issue with line: s |s	10
# Issue with line: r|ru	10
# Issue with line: rc|r	10
# Issue with line: p|t	10
# Issue with line: po|op	10
# Issue with line: o|oy	10
# Issue with line: op|po	10
# Issue with line: ng|gn	10
# Issue with line: j|jo	10
# Issue with line: h |h	10
# Issue with line: g|gs	10
# Issue with line: g|e	10
# Issue with line: e|'	10
# Issue with line: eu|e	10
# Issue with line: di|id	10
# Issue with line: bl|b	10
# Issue with line: ac|ca	10
# Issue with line: I|I'	10
# Issue with line: >l|>	10
# Issue with line: y'|y	9
# Issue with line: w|h	9
# Issue with line: un|nu	9
# Issue with line: s|n	9
# Issue with line: r|w	9
# Issue with line: pl|p	9
# Issue with line: om|mo	9
# Issue with line: od|o	9
# Issue with line: ob|o	9
# Issue with line: n|g	9
# Issue with line: nk|n	9
# Issue with line: mu|m	9
# Issue with line: ma|am	9
# Issue with line: l|u	9
# Issue with line: l|n	9
# Issue with line: k|a	9
# Issue with line: h|hl	9
# Issue with line: g|q	9
# Issue with line: gi|g	9
# Issue with line: gd|dg	9
# Issue with line: fa|f	9
# Issue with line: eg|ge	9
# Issue with line: e-|e	9
# Issue with line: d|dr	9
# Issue with line: d|dl	9
# Issue with line: dl|ld	9
# Issue with line: c|i	9
# Issue with line: cy|yc	9
# Issue with line: b|v	9
# Issue with line: a|s	9
# Issue with line: a|c	9
# Issue with line: ae|a	9
# Issue with line: R|r	9
# Issue with line: B|b	9
# Issue with line: A|E	9
# Issue with line: -| 	9
# Issue with line: y|ya	8
# Issue with line: x|s	8
# Issue with line: w|e	8
# Issue with line: wo|ow	8
# Issue with line: v|b	8
# Issue with line: u|ud	8
# Issue with line: u|u'	8
# Issue with line: um|u	8
# Issue with line: ud|u	8
# Issue with line: t|a	8
# Issue with line: tl|t	8
# Issue with line: s|su	8
# Issue with line: su|us	8
# Issue with line: p|m	8
# Issue with line: p|c	8
# Issue with line: p |p	8
# Issue with line: o|t	8
# Issue with line: os|so	8
# Issue with line: n|i	8
# Issue with line: n|a	8
# Issue with line: iv|vi	8
# Issue with line: hc|ch	8
# Issue with line: ge|eg	8
# Issue with line: fu|f	8
# Issue with line: e|ex	8
# Issue with line: e|ew	8
# Issue with line: ey|ye	8
# Issue with line: ef|fe	8
# Issue with line: d|dy	8
# Issue with line: d|du	8
# Issue with line: do|od	8
# Issue with line: c|n	8
# Issue with line: c|l	8
# Issue with line: c|C	8
# Issue with line: ct|tc	8
# Issue with line: ap|pa	8
# Issue with line: S|s	8
# Issue with line: C|c	8
# Issue with line: >|>g	8
# Issue with line: >|>c	8
# Issue with line: >|>b	8
# Issue with line: >o|>	8
# Issue with line: >b|>	8
# Issue with line: 'n|n'	8
# Issue with line: y|y'	7
# Issue with line: y|s	7
# Issue with line: ys|sy	7
# Issue with line: y-|y	7
# Issue with line: vi|iv	7
# Issue with line: ug|gu	7
# Issue with line: uc|cu	7
# Issue with line: t|ty	7
# Issue with line: t|f	7
# Issue with line: t-|t	7
# Issue with line: t'|t	7
# Issue with line: s|l	7
# Issue with line: s|f	7
# Issue with line: s'|s	7
# Issue with line: r|rl	7
# Issue with line: o|y	7
# Issue with line: o|ob	7
# Issue with line: oc|co	7
# Issue with line: n|nx	7
# Issue with line: l|lt	7
# Issue with line: lu|l	7
# Issue with line: lt|l	7
# Issue with line: iv|i	7
# Issue with line: ip|i	7
# Issue with line: h|p	7
# Issue with line: h|hs	7
# Issue with line: hy|h	7
# Issue with line: hw|wh	7
# Issue with line: g|x	7
# Issue with line: f|r	7
# Issue with line: e|g	7
# Issue with line: ea|ae	7
# Issue with line: d|s	7
# Issue with line: d|j	7
# Issue with line: d|do	7
# Issue with line: d|c	7
# Issue with line: d|a	7
# Issue with line: ds|d	7
# Issue with line: dn|nd	7
# Issue with line: bs|b	7
# Issue with line: a|n	7
# Issue with line: ao|oa	7
# Issue with line: af|a	7
# Issue with line: ab|a	7
# Issue with line: a'|a	7
# Issue with line: G|g	7
# Issue with line: >u|>	7
# Issue with line: >r|>	7
# Issue with line: xh|x	6
# Issue with line: w|wl	6
# Issue with line: w|v	6
# Issue with line: v|va	6
# Issue with line: ut|tu	6
# Issue with line: ui|iu	6
# Issue with line: t|y	6
# Issue with line: t|u	6
# Issue with line: t|g	6
# Issue with line: s|i	6
# Issue with line: s'|'s	6
# Issue with line: r|y	6
# Issue with line: r|c	6
# Issue with line: rt|tr	6
# Issue with line: r-|r	6
# Issue with line: p|r	6
# Issue with line: ow|wo	6
# Issue with line: nu|un	6
# Issue with line: m|t	6
# Issue with line: m|d	6
# Issue with line: ms|m	6
# Issue with line: m |m	6
# Issue with line: l|ld	6
# Issue with line: l|a	6
# Issue with line: ls|l	6
# Issue with line: lp|pl	6
# Issue with line: k|u	6
# Issue with line: k|kn	6
# Issue with line: ks|k	6
# Issue with line: ka|ak	6
# Issue with line: i|iz	6
# Issue with line: ig|i	6
# Issue with line: h|s	6
# Issue with line: h|r	6
# Issue with line: h|o	6
# Issue with line: h|k	6
# Issue with line: h|hr	6
# Issue with line: h|hn	6
# Issue with line: g|u	6
# Issue with line: gs|g	6
# Issue with line: gn|ng	6
# Issue with line: f|l	6
# Issue with line: fi|if	6
# Issue with line: e|w	6
# Issue with line: eh|he	6
# Issue with line: cr|c	6
# Issue with line: ag|a	6
# Issue with line: I|It	6
# Issue with line: >p|>	6
# Issue with line: |e	6
# Issue with line: z|x	5
# Issue with line: z|c	5
# Issue with line: y|t	5
# Issue with line: yl|ly	5
# Issue with line: yi|y	5
# Issue with line: ye|ey	5
# Issue with line: ya|ay	5
# Issue with line: w|wr	5
# Issue with line: w|wo	5
# Issue with line: w|o	5
# Issue with line: ws|sw	5
# Issue with line: wn|w	5
# Issue with line: ve|ev	5
# Issue with line: va|v	5
# Issue with line: ug|u	5
# Issue with line: t|m	5
# Issue with line: tu|ut	5
# Issue with line: tn|nt	5
# Issue with line: s|y	5
# Issue with line: s|u	5
# Issue with line: s|p	5
# Issue with line: sy|ys	5
# Issue with line: sr|rs	5
# Issue with line: sl|s	5
# Issue with line: s-|s	5
# Issue with line: r|rm	5
# Issue with line: r|g	5
# Issue with line: r|b	5
# Issue with line: r'|r	5
# Issue with line: pu|p	5
# Issue with line: o|o-	5
# Issue with line: ot|to	5
# Issue with line: oh|ho	5
# Issue with line: n|c	5
# Issue with line: nw|wn	5
# Issue with line: no|on	5
# Issue with line: nl|n	5
# Issue with line: nh|n	5
# Issue with line: m|p	5
# Issue with line: m|m'	5
# Issue with line: m|b	5
# Issue with line: mu|um	5
# Issue with line: l|y	5
# Issue with line: l|m	5
# Issue with line: l|lu	5
# Issue with line: k|ki	5
# Issue with line: kn|nk	5
# Issue with line: k-|k	5
# Issue with line: i|iu	5
# Issue with line: g|m	5
# Issue with line: g|gt	5
# Issue with line: gt|g	5
# Issue with line: go|g	5
# Issue with line: f|g	5
# Issue with line: f|fa	5
# Issue with line: ft|f	5
# Issue with line: fl|f	5
# Issue with line: e|l	5
# Issue with line: ew|e	5
# Issue with line: eu|ue	5
# Issue with line: ek|ke	5
# Issue with line: d|v	5
# Issue with line: d|u	5
# Issue with line: dr|d	5
# Issue with line: dn|d	5
# Issue with line: c|h	5
# Issue with line: cq|c	5
# Issue with line: b|m	5
# Issue with line: br|b	5
# Issue with line: bi|b	5
# Issue with line: I|i	5
# Issue with line: >c|>	5
# Issue with line: '|e	5
# Issue with line: y|n	4
# Issue with line: yr|ry	4
# Issue with line: x|xt	4
# Issue with line: xz|x	4
# Issue with line: xi|x	4
# Issue with line: w|wa	4
# Issue with line: w|s	4
# Issue with line: we|ew	4
# Issue with line: w |w	4
# Issue with line: v|vo	4
# Issue with line: v|t	4
# Issue with line: v|n	4
# Issue with line: vy|v	4
# Issue with line: u|t	4
# Issue with line: up|u	4
# Issue with line: uo|u	4
# Issue with line: t|tc	4
# Issue with line: t|b	4
# Issue with line: ty|t	4
# Issue with line: to|ot	4
# Issue with line: tm|t	4
# Issue with line: tl|lt	4
# Issue with line: s|w	4
# Issue with line: s|sk	4
# Issue with line: s|s'	4
# Issue with line: s|S	4
# Issue with line: sy|s	4
# Issue with line: sp|ps	4
# Issue with line: sn|ns	4
# Issue with line: sl|ls	4
# Issue with line: r|x	4
# Issue with line: r|rk	4
# Issue with line: r|rg	4
# Issue with line: r|h	4
# Issue with line: p|ps	4
# Issue with line: p|pn	4
# Issue with line: pm|mp	4
# Issue with line: o|l	4
# Issue with line: ou|uo	4
# Issue with line: oe|eo	4
# Issue with line: n|w	4
# Issue with line: n|b	4
# Issue with line: nm|n	4
# Issue with line: m|x	4
# Issue with line: m|mu	4
# Issue with line: mt|m	4
# Issue with line: mr|m	4
# Issue with line: mb|m	4
# Issue with line: l|lc	4
# Issue with line: lt|tl	4
# Issue with line: lc|cl	4
# Issue with line: lb|bl	4
# Issue with line: k|d	4
# Issue with line: j|ju	4
# Issue with line: j|d	4
# Issue with line: i|w	4
# Issue with line: i|r	4
# Issue with line: i|n	4
# Issue with line: iz|i	4
# Issue with line: iy|i	4
# Issue with line: hs|h	4
# Issue with line: g|s	4
# Issue with line: g|gy	4
# Issue with line: g|go	4
# Issue with line: gr|g	4
# Issue with line: go|og	4
# Issue with line: gd|g	4
# Issue with line: f|t	4
# Issue with line: f|p	4
# Issue with line: f|n	4
# Issue with line: f|c	4
# Issue with line: e|m	4
# Issue with line: e|eg	4
# Issue with line: ez|e	4
# Issue with line: ev|e	4
# Issue with line: ek|e	4
# Issue with line: d|w	4
# Issue with line: d|l	4
# Issue with line: dg|d	4
# Issue with line: d-|d	4
# Issue with line: cy|c	4
# Issue with line: cu|uc	4
# Issue with line: b|bs	4
# Issue with line: b|ba	4
# Issue with line: b-|b	4
# Issue with line: b |b	4
# Issue with line: a|A	4
# Issue with line: >|>n	4
# Issue with line: >'|>	4
# Issue with line: |p	4
# Issue with line: ze|ez	3
# Issue with line: y|w	3
# Issue with line: y|r	3
# Issue with line: y|c	3
# Issue with line: yr|y	3
# Issue with line: xt|x	3
# Issue with line: w|ws	3
# Issue with line: wo|w	3
# Issue with line: v|x	3
# Issue with line: v|w	3
# Issue with line: v|i	3
# Issue with line: v|c	3
# Issue with line: u|m	3
# Issue with line: ub|u	3
# Issue with line: t|w	3
# Issue with line: td|t	3
# Issue with line: s|m	3
# Issue with line: s|g	3
# Issue with line: so|os	3
# Issue with line: sn|s	3
# Issue with line: sm|ms	3
# Issue with line: sd|s	3
# Issue with line: r|r-	3
# Issue with line: rm|r	3
# Issue with line: rh|r	3
# Issue with line: p|s	3
# Issue with line: p|pu	3
# Issue with line: p|h	3
# Issue with line: pi|ip	3
# Issue with line: o|w	3
# Issue with line: o|r	3
# Issue with line: o|ov	3
# Issue with line: o|h	3
# Issue with line: oy|o	3
# Issue with line: oh|o	3
# Issue with line: oa|ao	3
# Issue with line: n|y	3
# Issue with line: n|f	3
# Issue with line: nr|n	3
# Issue with line: nk|kn	3
# Issue with line: n-|n	3
# Issue with line: m|w	3
# Issue with line: m|s	3
# Issue with line: m|r	3
# Issue with line: m|m-	3
# Issue with line: m|M	3
# Issue with line: mp|m	3
# Issue with line: l|s	3
# Issue with line: l|k	3
# Issue with line: l|f	3
# Issue with line: l|c	3
# Issue with line: lm|l	3
# Issue with line: k|p	3
# Issue with line: k|l	3
# Issue with line: k|k'	3
# Issue with line: kr|rk	3
# Issue with line: i|iv	3
# Issue with line: i|ib	3
# Issue with line: ih|hi	3
# Issue with line: i-|i	3
# Issue with line: h|c	3
# Issue with line: hl|h	3
# Issue with line: hg|h	3
# Issue with line: g|r	3
# Issue with line: g|gl	3
# Issue with line: gq|g	3
# Issue with line: gn|g	3
# Issue with line: f|s	3
# Issue with line: f|e	3
# Issue with line: f|F	3
# Issue with line: e|p	3
# Issue with line: e|k	3
# Issue with line: d|p	3
# Issue with line: d|m	3
# Issue with line: d|k	3
# Issue with line: d|i	3
# Issue with line: du|ud	3
# Issue with line: dh|d	3
# Issue with line: c|u	3
# Issue with line: c|r	3
# Issue with line: c|f	3
# Issue with line: c|d	3
# Issue with line: cs|sc	3
# Issue with line: cn|nc	3
# Issue with line: b|r	3
# Issue with line: by|b	3
# Issue with line: a|w	3
# Issue with line: a|h	3
# Issue with line: a|aw	3
# Issue with line: aw|a	3
# Issue with line: av|va	3
# Issue with line: as|sa	3
# Issue with line: ak|a	3
# Issue with line: ah|a	3
# Issue with line: M|m	3
# Issue with line: B|Br	3
# Issue with line: >|>y	3
# Issue with line: >g|>	3
# Issue with line: >f|>	3
# Issue with line: z|ze	2
# Issue with line: z|g	2
# Issue with line: ze|z	2
# Issue with line: y|yp	2
# Issue with line: y|yo	2
# Issue with line: y|yl	2
# Issue with line: y|yc	2
# Issue with line: y|v	2
# Issue with line: y|l	2
# Issue with line: y|h	2
# Issue with line: y|g	2
# Issue with line: y|a	2
# Issue with line: yu|y	2
# Issue with line: yt|y	2
# Issue with line: ym|y	2
# Issue with line: yl|y	2
# Issue with line: yd|dy	2
# Issue with line: x|z	2
# Issue with line: x|xp	2
# Issue with line: x|xe	2
# Issue with line: x|xa	2
# Issue with line: x|t	2
# Issue with line: x|n	2
# Issue with line: xe|ex	2
# Issue with line: xa|x	2
# Issue with line: x |x	2
# Issue with line: w|wn	2
# Issue with line: w|wi	2
# Issue with line: w|wd	2
# Issue with line: w|m	2
# Issue with line: w|l	2
# Issue with line: w|k	2
# Issue with line: w|a	2
# Issue with line: wl|w	2
# Issue with line: v|l	2
# Issue with line: v|g	2
# Issue with line: va|av	2
# Issue with line: u|h	2
# Issue with line: uh|u	2
# Issue with line: uf|fu	2
# Issue with line: t|tg	2
# Issue with line: t|j	2
# Issue with line: t|T	2
# Issue with line: tr|rt	2
# Issue with line: tg|t	2
# Issue with line: tc|t	2
# Issue with line: s|sm	2
# Issue with line: s|h	2
# Issue with line: sz|s	2
# Issue with line: sr|s	2
# Issue with line: sp|s	2
# Issue with line: sk|ks	2
# Issue with line: r|v	2
# Issue with line: r|R	2
# Issue with line: rw|r	2
# Issue with line: rp|pr	2
# Issue with line: rg|r	2
# Issue with line: rd|dr	2
# Issue with line: rb|r	2
# Issue with line: q|t	2
# Issue with line: q|a	2
# Issue with line: qt|q	2
# Issue with line: p|a	2
# Issue with line: p|P	2
# Issue with line: py|p	2
# Issue with line: pu|up	2
# Issue with line: ps|sp	2
# Issue with line: pl|lp	2
# Issue with line: o|ok	2
# Issue with line: o|g	2
# Issue with line: og|o	2
# Issue with line: og|go	2
# Issue with line: od|do	2
# Issue with line: o-|o	2
# Issue with line: n|o	2
# Issue with line: n|nk	2
# Issue with line: n|nj	2
# Issue with line: n|nf	2
# Issue with line: n|e	2
# Issue with line: ny|n	2
# Issue with line: nr|rn	2
# Issue with line: nm|mn	2
# Issue with line: nf|n	2
# Issue with line: m|f	2
# Issue with line: m|e	2
# Issue with line: my|m	2
# Issue with line: ms|sm	2
# Issue with line: mr|rm	2
# Issue with line: l|v	2
# Issue with line: l|p	2
# Issue with line: l|lv	2
# Issue with line: l|l-	2
# Issue with line: l|j	2
# Issue with line: l|g	2
# Issue with line: ly|yl	2
# Issue with line: lp|l	2
# Issue with line: ln|nl	2
# Issue with line: lf|l	2
# Issue with line: ld|l	2
# Issue with line: k|y	2
# Issue with line: k|x	2
# Issue with line: k|s	2
# Issue with line: k|o	2
# Issue with line: k|k-	2
# Issue with line: ki|k	2
# Issue with line: j|je	2
# Issue with line: j|h	2
# Issue with line: j|J	2
# Issue with line: ju|j	2
# Issue with line: jo|j	2
# Issue with line: i|s	2
# Issue with line: i|d	2
# Issue with line: i|E	2
# Issue with line: iy|yi	2
# Issue with line: iw|wi	2
# Issue with line: ih|i	2
# Issue with line: ib|i	2
# Issue with line: i |i	2
# Issue with line: h|l	2
# Issue with line: h|hm	2
# Issue with line: h|h-	2
# Issue with line: h|f	2
# Issue with line: hp|ph	2
# Issue with line: hn|h	2
# Issue with line: hm|h	2
# Issue with line: g|y	2
# Issue with line: gl|g	2
# Issue with line: gj|g	2
# Issue with line: f|fy	2
# Issue with line: f|fu	2
# Issue with line: f|d	2
# Issue with line: f|b	2
# Issue with line: e|f	2
# Issue with line: e|ez	2
# Issue with line: e|ep	2
# Issue with line: e|eh	2
# Issue with line: e|e-	2
# Issue with line: e| 	2
# Issue with line: ez|ze	2
# Issue with line: ew|we	2
# Issue with line: eh|e	2
# Issue with line: eb|e	2
# Issue with line: eb|be	2
# Issue with line: d|y	2
# Issue with line: d|dh	2
# Issue with line: d|d-	2
# Issue with line: d|d'	2
# Issue with line: dl|d	2
# Issue with line: da|ad	2
# Issue with line: c|z	2
# Issue with line: c|w	2
# Issue with line: c|v	2
# Issue with line: c|e	2
# Issue with line: c|cy	2
# Issue with line: c|cq	2
# Issue with line: cp|c	2
# Issue with line: b|t	2
# Issue with line: b|n	2
# Issue with line: b|f	2
# Issue with line: b|bt	2
# Issue with line: b|B	2
# Issue with line: bt|b	2
# Issue with line: bi|ib	2
# Issue with line: a|p	2
# Issue with line: a|m	2
# Issue with line: a|av	2
# Issue with line: a|ak	2
# Issue with line: ad|da	2
# Issue with line: ab|ba	2
# Issue with line: a-|a	2
# Issue with line: S|Z	2
# Issue with line: F|f	2
# Issue with line: E|Ea	2
# Issue with line: C|Ch	2
# Issue with line: A|a	2
# Issue with line: >|>v	2
# Issue with line: >|>l	2
# Issue with line: >y|>	2
# Issue with line: -|y	2
# Issue with line: |y	2
# Issue with line: |n	2
# Issue with line: |h	2
# Issue with line: z|zv	1
# Issue with line: z|zi	1
# Issue with line: z|za	1
# Issue with line: z|t	1
# Issue with line: z|l	1
# Issue with line: z|d	1
# Issue with line: zs|z	1
# Issue with line: zi|iz	1
# Issue with line: y|yw	1
# Issue with line: y|yi	1
# Issue with line: y|m	1
# Issue with line: y|j	1
# Issue with line: y|d	1
# Issue with line: yt|ty	1
# Issue with line: yn|y	1
# Issue with line: yn|ny	1
# Issue with line: yd|y	1
# Issue with line: yc|cy	1
# Issue with line: ya|y	1
# Issue with line: x|y	1
# Issue with line: x|xq	1
# Issue with line: x|m	1
# Issue with line: x|l	1
# Issue with line: xq|x	1
# Issue with line: xp|x	1
# Issue with line: xl|x	1
# Issue with line: xg|x	1
# Issue with line: xe|x	1
# Issue with line: w|y	1
# Issue with line: w|wy	1
# Issue with line: w|w-	1
# Issue with line: w|t	1
# Issue with line: w|i	1
# Issue with line: w|f	1
# Issue with line: w|d	1
# Issue with line: w|b	1
# Issue with line: w|W	1
# Issue with line: w|-	1
# Issue with line: w| 	1
# Issue with line: wt|tw	1
# Issue with line: ws|w	1
# Issue with line: wr|w	1
# Issue with line: wp|w	1
# Issue with line: wi|w	1
# Issue with line: wd|w	1
# Issue with line: wa|w	1
# Issue with line: wa|aw	1
# Issue with line: v|z	1
# Issue with line: v|y	1
# Issue with line: v|u	1
# Issue with line: v|p	1
# Issue with line: v|m	1
# Issue with line: v|d	1
# Issue with line: v|V	1
# Issue with line: vr|v	1
# Issue with line: vo|ov	1
# Issue with line: vn|v	1
# Issue with line: vl|v	1
# Issue with line: vc|v	1
# Issue with line: vb|v	1
# Issue with line: u|v	1
# Issue with line: u|uo	1
# Issue with line: u|j	1
# Issue with line: u|g	1
# Issue with line: u|f	1
# Issue with line: u|c	1
# Issue with line: uv|u	1
# Issue with line: up|pu	1
# Issue with line: uh|hu	1
# Issue with line: t|x	1
# Issue with line: t|tn	1
# Issue with line: t|tm	1
# Issue with line: t|t-	1
# Issue with line: t|q	1
# Issue with line: tx|xt	1
# Issue with line: tj|t	1
# Issue with line: tf|t	1
# Issue with line: tf|ft	1
# Issue with line: tc|ct	1
# Issue with line: tb|t	1
# Issue with line: s|v	1
# Issue with line: s|sn	1
# Issue with line: s|sf	1
# Issue with line: s|o	1
# Issue with line: sw|s	1
# Issue with line: sm|s	1
# Issue with line: sk|s	1
# Issue with line: sf|s	1
# Issue with line: sc|cs	1
# Issue with line: r|rp	1
# Issue with line: r|o	1
# Issue with line: r|k	1
# Issue with line: r|j	1
# Issue with line: r|'	1
# Issue with line: rx|r	1
# Issue with line: rw|wr	1
# Issue with line: rv|r	1
# Issue with line: rp|r	1
# Issue with line: rf|r	1
# Issue with line: rc|cr	1
# Issue with line: qu|q	1
# Issue with line: p|y	1
# Issue with line: p|py	1
# Issue with line: p|o	1
# Issue with line: p|l	1
# Issue with line: p|i	1
# Issue with line: p|g	1
# Issue with line: p|d	1
# Issue with line: ps|p	1
# Issue with line: pn|p	1
# Issue with line: pc|p	1
# Issue with line: pa|ap	1
# Issue with line: p0|p	1
# Issue with line: o|s	1
# Issue with line: o|ox	1
# Issue with line: o|oh	1
# Issue with line: o|n	1
# Issue with line: o|d	1
# Issue with line: o|O	1
# Issue with line: o|'	1
# Issue with line: oz|zo	1
# Issue with line: ox|o	1
# Issue with line: o'|o	1
# Issue with line: n|z	1
# Issue with line: n|x	1
# Issue with line: n|v	1
# Issue with line: n|p	1
# Issue with line: n|nv	1
# Issue with line: n|np	1
# Issue with line: n|nm	1
# Issue with line: n|nl	1
# Issue with line: n|h	1
# Issue with line: n|N	1
# Issue with line: n| 	1
# Issue with line: nw|n	1
# Issue with line: nv|n	1
# Issue with line: np|n	1
# Issue with line: nb|n	1
# Issue with line: n | n	1
# Issue with line: m|v	1
# Issue with line: m|u	1
# Issue with line: m|.	1
# Issue with line: mn|nm	1
# Issue with line: md|m	1
# Issue with line: mc|m	1
# Issue with line: m-|m	1
# Issue with line: m'|m	1
# Issue with line: l|o	1
# Issue with line: l|lp	1
# Issue with line: l|ln	1
# Issue with line: l|lf	1
# Issue with line: l|l'	1
# Issue with line: l|h	1
# Issue with line: l|'	1
# Issue with line: lw|wl	1
# Issue with line: lw|l	1
# Issue with line: lr|l	1
# Issue with line: ln|l	1
# Issue with line: lh|l	1
# Issue with line: lg|l	1
# Issue with line: ld|dl	1
# Issue with line: lc|l	1
# Issue with line: lb|l	1
# Issue with line: k|kg	1
# Issue with line: kw|k	1
# Issue with line: kt|k	1
# Issue with line: kn|k	1
# Issue with line: kl|lk	1
# Issue with line: kh|k	1
# Issue with line: kg|k	1
# Issue with line: ke|ek	1
# Issue with line: kc|k	1
# Issue with line: kc|ck	1
# Issue with line: k'|k	1
# Issue with line: j|v	1
# Issue with line: j|t	1
# Issue with line: ji|j	1
# Issue with line: je|j	1
# Issue with line: i|Ã­	1
# Issue with line: i|x	1
# Issue with line: i|m	1
# Issue with line: i|j	1
# Issue with line: i|f	1
# Issue with line: i|I	1
# Issue with line: i|'	1
# Issue with line: ix|xi	1
# Issue with line: ix|i	1
# Issue with line: h|y	1
# Issue with line: h|w	1
# Issue with line: h|m	1
# Issue with line: h|j	1
# Issue with line: h|a	1
# Issue with line: h|H	1
# Issue with line: hx|xh	1
# Issue with line: hg|gh	1
# Issue with line: h-|h	1
# Issue with line: g|z	1
# Issue with line: g|p	1
# Issue with line: g|o	1
# Issue with line: g|l	1
# Issue with line: g|h	1
# Issue with line: g|g-	1
# Issue with line: g|f	1
# Issue with line: g|a	1
# Issue with line: g|G	1
# Issue with line: gr|rg	1
# Issue with line: gl|lg	1
# Issue with line: gk|g	1
# Issue with line: ga|ag	1
# Issue with line: g'|g	1
# Issue with line: f|w	1
# Issue with line: f|k	1
# Issue with line: f|i	1
# Issue with line: f|h	1
# Issue with line: fo|of	1
# Issue with line: fh|f	1
# Issue with line: e|Ã¨	1
# Issue with line: e|ev	1
# Issue with line: ex|xe	1
# Issue with line: eq|e	1
# Issue with line: d|z	1
# Issue with line: d|h	1
# Issue with line: d|f	1
# Issue with line: d|D	1
# Issue with line: dy|d	1
# Issue with line: du|d	1
# Issue with line: dt|d	1
# Issue with line: dr|rd	1
# Issue with line: dj|d	1
# Issue with line: df|d	1
# Issue with line: dc|d	1
# Issue with line: d'|d	1
# Issue with line: c|o	1
# Issue with line: c|b	1
# Issue with line: cx|xc	1
# Issue with line: cx|c	1
# Issue with line: cv|c	1
# Issue with line: co|oc	1
# Issue with line: cn|c	1
# Issue with line: c'|c	1
# Issue with line: b|w	1
# Issue with line: b|o	1
# Issue with line: b|l	1
# Issue with line: b|g	1
# Issue with line: b|e	1
# Issue with line: b|by	1
# Issue with line: b|b-	1
# Issue with line: b|a	1
# Issue with line: bu|ub	1
# Issue with line: br|rb	1
# Issue with line: bm|mb	1
# Issue with line: bh|b	1
# Issue with line: bd|b	1
# Issue with line: a|Ã¡	1
# Issue with line: a|f	1
# Issue with line: a|b	1
# Issue with line: a|ah	1
# Issue with line: a|a-	1
# Issue with line: a|a'	1
# Issue with line: a|I	1
# Issue with line: a|'	1
# Issue with line: ay|ya	1
# Issue with line: ax|a	1
# Issue with line: aw|wa	1
# Issue with line: av|a	1
# Issue with line: ao|a	1
# Issue with line: aj|a	1
# Issue with line: W|Wh	1
# Issue with line: V|v	1
# Issue with line: U|u	1
# Issue with line: T|Tr	1
# Issue with line: S|C	1
# Issue with line: Sh|S	1
# Issue with line: R|c	1
# Issue with line: O|o	1
# Issue with line: L|l	1
# Issue with line: K|k	1
# Issue with line: K|c	1
# Issue with line: J|g	1
# Issue with line: I|a	1
# Issue with line: He|H	1
# Issue with line: G|Ge	1
# Issue with line: Go|G	1
# Issue with line: Gh|G	1
# Issue with line: F|Fr	1
# Issue with line: E|En	1
# Issue with line: D|De	1
# Issue with line: C|g	1
# Issue with line: C|Co	1
# Issue with line: C|Ca	1
# Issue with line: B|M	1
# Issue with line: Ap|A	1
# Issue with line: >n|>	1
# Issue with line: >d|>	1
# Issue with line: >S|>	1
# Issue with line: >A|>	1
# Issue with line: -|s	1
# Issue with line: -|p	1
# Issue with line: -|l	1
# Issue with line: -|e	1
# Issue with line: -|'	1
# Issue with line: '|a	1
# Issue with line: '|'l	1
# Issue with line: 's|s'	1
# Issue with line: 'l|'	1
# Issue with line: 'e|'	1
# Issue with line: |r	1
# Issue with line: |o	1
# Issue with line: |l	1
# Issue with line: |k	1
# Issue with line: |i	1
# Issue with line: |c	1
# Issue with line: |a	1
# Issue with line: |'	1
# Issue with line: w| 	1
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\isaia\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!

# %% [markdown]
# # **Noisy Channel Model Implementation**
#
# *Again, you don't have to follow this directly, but consider placing your implementation of the model in the code block below.*

# %%
# Spell Check Function
def spell_check(word):
    if word in vocab:
        return f"No errors found in '{word}'"

    candidates = {}
    for w in vocab:
        if abs(len(word) - len(w)) > 1:
            continue

        if edit_distance(word, w) == 1:
            candidates[w] = edit_distance(word, w)

    if not candidates:
        return f"No suggestions found for '{word}'"

    output_data = []
    for candidate, edit_type in candidates.items():
        # Error Model Probability: P(c)
        p_c = 1  # Placeholder for P(c) probability

        # Probability of generating the user-input word from the candidate: P(w|c)
        p_w_given_c = 1.0 / (word_count + 1)  # Laplace smoothing; initialize to avoid zero probability

        if word_frequency[candidate] > 0:
            p_w_given_c = word_frequency[candidate] / word_count

        # Combining P(c) and P(w|c) for each candidate
        combined_probability = p_c * p_w_given_c

        output_data.append([word, candidate, edit_type, f'...', p_c, p_w_given_c, combined_probability])

    # Sort suggestions by combined probability in descending order
    output_data.sort(key=lambda x: x[6], reverse=True)

    # Return the suggestion with the highest combined probability
    best_suggestion = output_data[0]
    return tabulate(output_data, headers=["word", "candidate", "edit_type", "edit", "P(c)", "P(w|c)", "P(c) x P(w|c)"], tablefmt="pretty")

# Example
input_word = "mohter"
result = spell_check(input_word)
print(result)
# Out:
# +--------+-----------+-----------+------+------+-----------------------+-----------------------+
# |  word  | candidate | edit_type | edit | P(c) |        P(w|c)         |     P(c) x P(w|c)     |
# +--------+-----------+-----------+------+------+-----------------------+-----------------------+
# | mohter |  morter   |     1     | ...  |  1   | 4.195890087514824e-06 | 4.195890087514824e-06 |
# +--------+-----------+-----------+------+------+-----------------------+-----------------------+
